# %%
from matplotlib import pyplot
from sklearn.datasets import make_moons
from keras.models import Sequential
from keras.layers import Dense
X,Y=make_moons(n_samples=100,noise=0.2,random_state=1)
n_train=30
trainX,testX=X[:n_train,:],X[n_train:]
trainY,testY=Y[:n_train],Y[n_train:]
#print(trainX)
#print(trainY)
#print(testX) #print(testY)
model=Sequential()
model.add(Dense(500,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history=model.fit(trainX,trainY,validation_data=(testX,testY),epochs=10)
pyplot.plot(history.history['accuracy'],label='train')
pyplot.plot(history.history['val_accuracy'],label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.6823 - accuracy: 0.6667 - val_loss: 0.6791 - val_accuracy: 0.6286
# Epoch 2/10
# 1/1 [==============================] - 0s 86ms/step - loss: 0.6666 - accuracy: 0.8333 - val_loss: 0.6691 - val_accuracy: 0.7000
# Epoch 3/10
# 1/1 [==============================] - 0s 76ms/step - loss: 0.6514 - accuracy: 0.8333 - val_loss: 0.6595 - val_accuracy: 0.6857
# Epoch 4/10
# 1/1 [==============================] - 0s 79ms/step - loss: 0.6365 - accuracy: 0.8333 - val_loss: 0.6503 - val_accuracy: 0.6857
# Epoch 5/10
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6221 - accuracy: 0.8333 - val_loss: 0.6414 - val_accuracy: 0.6857
# Epoch 6/10
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6081 - accuracy: 0.8333 - val_loss: 0.6327 - val_accuracy: 0.6857
# Epoch 7/10
# 1/1 [==============================] - 0s 142ms/step - loss: 0.5945 - accuracy: 0.8333 - val_loss: 0.6244 - val_accuracy: 0.6857
# Epoch 8/10
# 1/1 [==============================] - 0s 191ms/step - loss: 0.5813 - accuracy: 0.8333 - val_loss: 0.6163 - val_accuracy: 0.6857
# Epoch 9/10
# 1/1 [==============================] - 0s 86ms/step - loss: 0.5684 - accuracy: 0.8667 - val_loss: 0.6085 - val_accuracy: 0.6857
# Epoch 10/10
# 1/1 [==============================] - 0s 110ms/step - loss: 0.5559 - accuracy: 0.8667 - val_loss: 0.6009 - val_accuracy: 0.7000

# %%
from matplotlib import pyplot
from sklearn.datasets import make_moons
from keras.models import Sequential
from keras.layers import Dense
from keras.regularizers import l2
X,Y=make_moons(n_samples=100,noise=0.2,random_state=1)
n_train=30
trainX,testX=X[:n_train,:],X[n_train:]
trainY,testY=Y[:n_train],Y[n_train:]
#print(trainX)
#print(trainY)
#print(testX) #print(testY)
model=Sequential()

model.add(Dense(500,input_dim=2,activation='relu'
,kernel_regularizer=l2(0.001)))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history=model.fit(trainX,trainY,validation_data=(testX,testY),epochs=10)
pyplot.plot(history.history['accuracy'],label='train')
pyplot.plot(history.history['val_accuracy'],label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.7240 - accuracy: 0.1667 - val_loss: 0.7075 - val_accuracy: 0.4286
# Epoch 2/10
# 1/1 [==============================] - 0s 102ms/step - loss: 0.7067 - accuracy: 0.5000 - val_loss: 0.6962 - val_accuracy: 0.4714
# Epoch 3/10
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6898 - accuracy: 0.5333 - val_loss: 0.6854 - val_accuracy: 0.5571
# Epoch 4/10
# 1/1 [==============================] - 0s 131ms/step - loss: 0.6735 - accuracy: 0.6333 - val_loss: 0.6749 - val_accuracy: 0.6000
# Epoch 5/10
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6576 - accuracy: 0.8000 - val_loss: 0.6649 - val_accuracy: 0.6286
# Epoch 6/10
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6423 - accuracy: 0.8333 - val_loss: 0.6552 - val_accuracy: 0.6857
# Epoch 7/10
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6275 - accuracy: 0.8333 - val_loss: 0.6459 - val_accuracy: 0.6857
# Epoch 8/10
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6132 - accuracy: 0.8333 - val_loss: 0.6370 - val_accuracy: 0.6857
# Epoch 9/10
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5993 - accuracy: 0.8333 - val_loss: 0.6285 - val_accuracy: 0.6857
# Epoch 10/10
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5858 - accuracy: 0.8333 - val_loss: 0.6202 - val_accuracy: 0.6857

# %%
from matplotlib import pyplot
from sklearn.datasets import make_moons
from keras.models import Sequential
from keras.layers import Dense
from keras.regularizers import l1_l2
X,Y=make_moons(n_samples=100,noise=0.2,random_state=1)
n_train=30
trainX,testX=X[:n_train,:],X[n_train:]
trainY,testY=Y[:n_train],Y[n_train:]
#print(trainX)
#print(trainY)
#print(testX)
#print(testY)

model=Sequential()
model.add(Dense(500,input_dim=2,activation='relu',kernel_regularizer=l1_l2(l1=0.001,l2=0.001)))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history=model.fit(trainX,trainY,validation_data=(testX,testY),epochs=10)
pyplot.plot(history.history['accuracy'],label='train')
pyplot.plot(history.history['val_accuracy'],label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.7527 - accuracy: 0.4667 - val_loss: 0.7420 - val_accuracy: 0.5286
# Epoch 2/10
# 1/1 [==============================] - 0s 48ms/step - loss: 0.7362 - accuracy: 0.4667 - val_loss: 0.7315 - val_accuracy: 0.7286
# Epoch 3/10
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7201 - accuracy: 0.9000 - val_loss: 0.7213 - val_accuracy: 0.7286
# Epoch 4/10
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7045 - accuracy: 0.9333 - val_loss: 0.7115 - val_accuracy: 0.7286
# Epoch 5/10
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6893 - accuracy: 0.9000 - val_loss: 0.7020 - val_accuracy: 0.7286
# Epoch 6/10
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6746 - accuracy: 0.9000 - val_loss: 0.6929 - val_accuracy: 0.7143
# Epoch 7/10
# 1/1 [==============================] - 0s 43ms/step - loss: 0.6604 - accuracy: 0.9000 - val_loss: 0.6842 - val_accuracy: 0.7143
# Epoch 8/10
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6465 - accuracy: 0.8667 - val_loss: 0.6758 - val_accuracy: 0.7143
# Epoch 9/10
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6331 - accuracy: 0.8667 - val_loss: 0.6677 - val_accuracy: 0.7143
# Epoch 10/10
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6200 - accuracy: 0.8667 - val_loss: 0.6600 - val_accuracy: 0.7143
